# %%
import googlemaps
import time

# Replace 'YOUR_API_KEY' with your actual API key.
gmaps = googlemaps.Client(key='AIzaSyD_quHnmS-Rx-cXN8bqd9S_82OhGKbvD94')

# List of neighborhoods in Toronto.
neighborhoods = [
    "Runnymede", "Bay Street Corridor", "Pleasantview","Runnymede","Bay Street Corridor","Pleasantview"
,"Humber Heights - Westmount","Junction Triangle","Old Town","Armour Heights","York University Heights","Trinity Bellwoods",
"Earlscourt","Sunnylea","Hillcrest","Kennedy Park","Don Mills","Agincourt","Danforth Village"
,"Ledbury Park","Cabbagetown","Oakwood - Vaughan", "Humber Summit"
,"Entertainment District"]

def get_places_by_neighborhood(neighborhood, gmaps_client):
    # Search for clothing stores in the neighborhood.
    # You can adjust the query to search for a different type of business.
    result = gmaps_client.places(query="clothing stores in " + neighborhood + " Toronto")
    
    # Extract the necessary information from each place.
    places_details = []
    for place in result.get('results', []):
        details = {
            'name': place['name'],
            'neighborhood': neighborhood,  # Add the neighborhood to the details
            'address': place.get('formatted_address'),
            'rating': place.get('rating'),
            'latitude': place['geometry']['location']['lat'],
            'longitude': place['geometry']['location']['lng']
        }
        places_details.append(details)
    return places_details

# Loop through all neighborhoods and get places information.
all_places = []
for neighborhood in neighborhoods:
    places = get_places_by_neighborhood(neighborhood, gmaps)
    all_places.extend(places)
    # Sleep to avoid exceeding the Places API rate limits.
    time.sleep(2)  # Sleep for 2 seconds; adjust as necessary based on your quota.

# At this point, `all_places` contains all the information.
# You can print it, save it to a file, or process it as needed.

# Example: Print the information.
for place in all_places:
    print(place)
# Out:
# {'name': "The Shoppe - Women's Fine Fashion", 'neighborhood': 'Runnymede', 'address': '256 Willard Ave, Toronto, ON M6S 3R2, Canada', 'rating': 4.2, 'latitude': 43.6501334, 'longitude': -79.48196349999999}
# {'name': 'Pink Martini Bloor', 'neighborhood': 'Runnymede', 'address': '2378 Bloor St W, Toronto, ON M6S 1P5, Canada', 'rating': 3.9, 'latitude': 43.6500672, 'longitude': -79.4822473}
# {'name': 'Cora Couture', 'neighborhood': 'Runnymede', 'address': '2236 Bloor St W, Toronto, ON M6S 1N6, Canada', 'rating': 4.5, 'latitude': 43.6511366, 'longitude': -79.4769261}
# {'name': "Cecil Ward & Sons Men's Shop", 'neighborhood': 'Runnymede', 'address': '2416 Bloor St W, Toronto, ON M6S 1P9, Canada', 'rating': 4.7, 'latitude': 43.6496796, 'longitude': -79.4835986}
# {'name': 'Bucks Hard Goods', 'neighborhood': 'Runnymede', 'address': '2240 Bloor St W, Toronto, ON M6S 1N1, Canada', 'rating': 4.9, 'latitude': 43.6511098, 'longitude': -79.4770423}
# ...

# %%
import pandas as pd
df = pd.DataFrame(all_places)
df.to_excel('Competitors_data1.xlsx', index=False)

# %%
import googlemaps
import time

# Replace 'YOUR_API_KEY' with your actual API key.
gmaps = googlemaps.Client(key='AIzaSyD_quHnmS-Rx-cXN8bqd9S_82OhGKbvD94')

# List of neighborhoods in Toronto.
neighborhoods = [
    "St. Lawrence","Amesbury","Smithfield","Emery","Davisville Village","Syme","Leaside","Harbord Village","Curran Hall","Niagara","Fairbank","Willowdale","Silverthorn","Garden District"
,"The Beach","Casa Loma","Clairlea","The Annex","High Park","Malvern","Palmerston - Little Italy","Fashion District","Financial District","Sherwood Park"
,"St. James Town","Cedarvale","North Toronto","Downsview","The Upper Beaches","Liberty Village","Leslieville","The Queensway","Davenport","Bedford Park"
,"King West Village","The Junction","Moss Park","Weston","Bayview Village","Dovercourt Park","Church and Wellesley","Grange Park","West Humber - Clairville","Beaconsfield Village"
,"Roncesvalles","Yorkville","Jane and Finch","Allenby","Wilson Heights - Dublin Heights - Clanton Park","Alexandra Park","Glen Park","Bloor West Village"
,"Kensington","Seaton Village","Deer Park","Bendale", "Riverdale"]

def get_places_by_neighborhood(neighborhood, gmaps_client):
    # Search for clothing stores in the neighborhood.
    # You can adjust the query to search for a different type of business.
    result = gmaps_client.places(query="clothing stores in " + neighborhood + " Toronto")
    
    # Extract the necessary information from each place.
    places_details = []
    for place in result.get('results', []):
        details = {
            'name': place['name'],
            'neighborhood': neighborhood,  # Add the neighborhood to the details
            'address': place.get('formatted_address'),
            'rating': place.get('rating'),
            'latitude': place['geometry']['location']['lat'],
            'longitude': place['geometry']['location']['lng']
        }
        places_details.append(details)
    return places_details

# Loop through all neighborhoods and get places information.
all_places = []
for neighborhood in neighborhoods:
    places = get_places_by_neighborhood(neighborhood, gmaps)
    all_places.extend(places)
    # Sleep to avoid exceeding the Places API rate limits.
    time.sleep(2)  # Sleep for 2 seconds; adjust as necessary based on your quota.

# At this point, `all_places` contains all the information.
# You can print it, save it to a file, or process it as needed.

# Example: Print the information.
for place in all_places:
    print(place)
# Out:
# {'name': 'Kochi Stores', 'neighborhood': 'St. Lawrence', 'address': '83 Front St E, Toronto, ON M5E 1Z7, Canada', 'rating': 4.7, 'latitude': 43.6488098, 'longitude': -79.3724527}
# {'name': 'Faamaar Clothings', 'neighborhood': 'St. Lawrence', 'address': 'Princess St, Toronto, ON M5A 2C7, Canada', 'rating': 0, 'latitude': 43.6496244, 'longitude': -79.366489}
# {'name': 'Winners', 'neighborhood': 'St. Lawrence', 'address': '45 Front St E #35, Toronto, ON M5E 1B3, Canada', 'rating': 4.2, 'latitude': 43.6477653, 'longitude': -79.3745565}
# {'name': 'Appareliii Inc.', 'neighborhood': 'St. Lawrence', 'address': '18 King St E Suite #1400, Toronto, ON M5C 1C4, Canada', 'rating': 5, 'latitude': 43.6495557, 'longitude': -79.37701299999999}
# {'name': 'Peace Collective', 'neighborhood': 'St. Lawrence', 'address': '7 Trinity St, Toronto, ON M5A 3C4, Canada', 'rating': 4.9, 'latitude': 43.6499895, 'longitude': -79.35925399999999}
# ...

# %%
import pandas as pd
df = pd.DataFrame(all_places)
df.to_excel('Competitors_data2.xlsx', index=False)
